# %%
# !pip install /lakehouse/default/Files/repo/FabricSync-0.0.1-py3-none-any.whl
# Out:
# StatementMeta(, 79760a5e-e9e4-48ef-b651-079b12b8e4e2, 4, Finished, Available)
# Processing /lakehouse/default/Files/repo/FabricSync-0.0.1-py3-none-any.whl
# ...

# %%
from BQ import *
# Out:
# StatementMeta(, 79760a5e-e9e4-48ef-b651-079b12b8e4e2, 10, Finished, Available)
