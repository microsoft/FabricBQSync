# %%
# !pip install /lakehouse/default/Files/repo/FabricSync-0.0.1-py3-none-any.whl --force-reinstall
# Out:
# StatementMeta(, 9ff228e5-b371-4b68-8d25-dd31ef9bc30c, 13, Finished, Available)
# Processing /lakehouse/default/Files/repo/FabricSync-0.0.1-py3-none-any.whl
# Installing collected packages: FabricSync
#   Attempting uninstall: FabricSync
#     Found existing installation: FabricSync 0.0.1
#     Uninstalling FabricSync-0.0.1:
#       Successfully uninstalled FabricSync-0.0.1
# Successfully installed FabricSync-0.0.1

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *
from datetime import datetime, timezone
import json
from json import JSONEncoder
import base64
from pathlib import Path
import os
# Out:
# StatementMeta(, 9ff228e5-b371-4b68-8d25-dd31ef9bc30c, 15, Finished, Available)

# %%
from FabricSync.BQ.FabricLoader import *
# Out:
# StatementMeta(, 9ff228e5-b371-4b68-8d25-dd31ef9bc30c, 16, Finished, Available)
