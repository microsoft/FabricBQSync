# %% [markdown]
# ## Import Required Helper Classes

# %%
# %run BQ_Sync_Lib
# Out:
# StatementMeta(, 218d6d60-bde9-4c15-aedd-c7542a2983b5, 28, Finished, Available)

# %%
config_json_path = "Files/config/fabric-poc-bq-config.json"
# Out:
# StatementMeta(, 218d6d60-bde9-4c15-aedd-c7542a2983b5, 29, Finished, Available)

# %% [markdown]
# ## Create Required Supporting Tables & Data
#
# Using the default lakehouse create the following tables:
# - bq_data_type_map
# - bq_sync_configuration
# - bq_sync_schedule
# - bq_sync_schedule_telemetry
#
# The data type map table is also loaded with the required supporting data

# %%
setup = SyncSetup(config_json_path)
setup.setup()
# Out:
# StatementMeta(, 218d6d60-bde9-4c15-aedd-c7542a2983b5, 30, Finished, Available)
