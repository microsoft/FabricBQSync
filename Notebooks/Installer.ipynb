# %% [markdown]
# # BQ Sync Automated Installer
#
# Before you begin:
# 1. Attached this notebook to a lakehouse within the workspace you want the artifacts deployed.
#     - If the workspace is new, create a new lakehouse for the BQ Sync Metadata. For example: <code>BQSync_Metdata</code>
#
#     <br />
#     Please note, the lakehouse you attach doesn't need to be one used for the sync process. The installer will create the required lakehouses if they do not exists.
#     <br />
#     <br />
# 2. Start your sessions and walk-through the installer notebook
# 3. Update the environment configuration data as required below

# %%
# !pip install semantic-link --q
# Out:
# StatementMeta(, 6ceb897f-b641-4e39-a708-8a0b5b1f68d3, 3, Finished, Available)

# %%
# !pip install PyGithub --q
# Out:
# StatementMeta(, 6ceb897f-b641-4e39-a708-8a0b5b1f68d3, 4, Finished, Available)

# %%
sc.addPyFile('/lakehouse/default/Files/FabricAPI.py')
sc.addPyFile('/lakehouse/default/Files/FabricSetup.py')
# Out:
# StatementMeta(, 6ceb897f-b641-4e39-a708-8a0b5b1f68d3, 5, Finished, Available)

# %% [markdown]
# ### Configure your Environment
#
# 1. Metadata Lakehouse - name of the lakehouse used to drive the BQ Sync process (Created if it doesn't exists)
# 2. Target Lakehouse - name of the lakehouse where the BQ Sync data will be landed (Created if it doesn't exists)
# 3. GCP Project ID - the GCP billing project that contains the in-scope dataset
# 4. GCP Dataset - the BQ dataset containing the data to be synced
# 5. GCP Service Credential JSON File
#     - Upload your GCP Credential file to the attached lakehouse
#     - The <code>gcp_credential_path</code> is the File API Path to your JSON credential file <br />
#     Example: <code>/lakehouse/default/Files/my-credential-file.json"</code>

# %%
from FabricAPI import FabricAPIUtil
from FabricSetup import SetupUtil
# Out:
# StatementMeta(, 6ceb897f-b641-4e39-a708-8a0b5b1f68d3, 6, Finished, Available)

# %%
data = {
    "metadata_lakehouse":"Sync_Metadata",
    "target_lakehouse":"DW",
    "gcp_project_id":"fabric-poc-416917",
    "gcp_dataset_id":"EDW",
    "gcp_credential_path":"/lakehouse/default/Files/fabric-poc-416917-efd8038af977.json"
}
# Out:
# StatementMeta(, 6ceb897f-b641-4e39-a708-8a0b5b1f68d3, 7, Finished, Available)

# %%
setup_util = SetupUtil(spark)
setup_util.run_installer(data)
# Out:
# StatementMeta(, 6ceb897f-b641-4e39-a708-8a0b5b1f68d3, 8, Finished, Available)
# Starting BQ Sync Installer...
# BQ Sync Installer Finished!
