# %%
load_group = "999"
config_json_path = "Files/config/fabric-poc-bq-config.json"

# %%
from FabricSync.BQ.Loader import *

schedule_loader = BQScheduleLoader(spark, mssparkutils, config_json_path)
schedule_loader.process_load_group_telemetry(load_group)
