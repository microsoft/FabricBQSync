# %%
# %run Loader

# %%
load_group = "999"
config_json_path = "Files/config/fabric-poc-bq-config.json"

# %%
print(f"Checkpointing Load Group {load_group}...")

# %%
schedule_loader = BQScheduleLoader(config_json_path)
schedule_loader.process_load_group_telemetry(load_group)
